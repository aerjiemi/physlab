# %%
import pandas as pd 

df = pd.read_excel("lab11.xlsx")
df.columns
# Out:
# Index(['I1', 'I2', 'm1', 'T2', 'T3', 'U1', 'U1Max', 'U3', 'U4', 'U5', 'U6',
#        'Um2', 'p2', 'pm', 'pm2', 'pt', 'pt2', 'tp1', 'tp2', 'tpf1', 'tpf2'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

t_data = df['T2']
u_data = df['U1']
p_data = df['U1'] * df['I1']
p_avg = p_data.mean()

# Напряжение
ax1.plot(t_data, u_data, color='red', label='U1(t)', linewidth=1.5, alpha=0.8)
ax1.set_xlabel('Время T, с')
ax1.set_ylabel('Напряжение U1, В', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.grid(True, which='both', linestyle='--', alpha=0.5)

# Мощность
ax2 = ax1.twinx()
ax2.plot(t_data, p_data, color='green', label='P(t)', linewidth=2)
ax2.axhline(y=p_avg, color='darkorange', linestyle=':', label=f'P_ср = {p_avg:.3f} Вт')
ax2.set_ylabel('Мощность P, Вт', color='green')
ax2.tick_params(axis='y', labelcolor='green')


p_max = p_data.max()
u_max = u_data.max()
info_text = (f"U_max = {u_max:.2f} В\n"
             f"P_max = {p_max:.3f} Вт\n"
             f"P_avg = {p_avg:.3f} Вт")

plt.text(0.05, 0.95, info_text, transform=ax1.transAxes, fontsize=10,
         verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))


lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

plt.title('Мгновенные значения напряжения U(t) и мощности P(t)')
fig.tight_layout()

plt.savefig('U_P_plot.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd


t_data = df['T2'] 
u_data = df['U1']
i_data = df['I1']

fig1, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(t_data, u_data, color='red', label='U1(t)', linewidth=1.5)
ax1.set_xlabel('Время T, с')
ax1.set_ylabel('Напряжение U1, В', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.grid(True, which='both', linestyle='--', alpha=0.5)

ax2 = ax1.twinx()
ax2.plot(t_data, i_data, color='blue', linestyle='--', label='I1(t)', linewidth=1.5)
ax2.set_ylabel('Ток I1, А', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')


plt.title('Мгновенные значения U(t) и I(t)')
fig1.tight_layout()
plt.savefig('U_I_plot.png')
plt.show()

# %%
# РЕАКТИВНОЕ 

t_data = df['T3']
u_data = df['U5']
i_data = df['I2']
p_data = u_data * i_data
p_avg = p_data.mean()

fig1, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(t_data, u_data, color='blue', label='U(t), В', linewidth=1.5)
ax1.set_xlabel('Время T, с')
ax1.set_ylabel('Напряжение U, В', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True, linestyle='--', alpha=0.6)

ax2 = ax1.twinx()
ax2.plot(t_data, i_data, color='red', linestyle='--', label='I(t), А', linewidth=1.5)
ax2.set_ylabel('Ток I, А', color='red')
ax2.tick_params(axis='y', labelcolor='red')

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

plt.title('Реактивная нагрузка: Ток и Напряжение ')
fig1.tight_layout()
plt.show()

fig2, ax3 = plt.subplots(figsize=(10, 5))

ax3.plot(t_data, u_data, color='red', label='U(t), В', linewidth=1.2, alpha=0.6)
ax3.set_xlabel('Время T, с')
ax3.set_ylabel('Напряжение U, В', color='red')
ax3.tick_params(axis='y', labelcolor='red')
ax3.grid(True, linestyle='--', alpha=0.6)

ax4 = ax3.twinx()
ax4.plot(t_data, p_data, color='green', label='P(t), Вт', linewidth=2)
ax4.axhline(y=0, color='black', linewidth=1) # Линия нуля для наглядности
ax4.axhline(y=p_avg, color='darkorange', linestyle=':', label=f'P_ср = {p_avg:.4f} Вт')
ax4.set_ylabel('Мощность P, Вт', color='green')
ax4.tick_params(axis='y', labelcolor='green')

# Объединение легенд
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
ax4.legend(lines3 + lines4, labels3 + labels4, loc='upper right')

plt.title('Реактивная нагрузка: Напряжение и Мгновенная мощность')
fig2.tight_layout()
plt.show()
